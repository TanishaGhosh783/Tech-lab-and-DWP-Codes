# %% [markdown]
# <a href="https://colab.research.google.com/github/TanishaGhosh783/Tech-lab-and-DWP-Codes/blob/main/DWP%20Prac%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Wrangling

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder,OneHotEncoder


#sample data
data={
    'Color':['Red','Green','Blue','Green','Red','Blue'],
    'Size':['s','m','l','m','l','s'],
    'Category':['A','B','A','A','B','C']
}

#creating data frame
df=pd.DataFrame(data)
df
# Out:
#    Color Size Category
# 0    Red    s        A
# 1  Green    m        B
# 2   Blue    l        A
# 3  Green    m        A
# 4    Red    l        B
# 5   Blue    s        C

# %%
#------------- 1.One Hot Encoding ------------------
one_hot=pd.get_dummies(df['Color'],dtype='int')
df_one_hot=pd.concat([df,one_hot],axis=1)

print("\nHot Encoding:")
print(df_one_hot)
# Out:
# Hot Encoding:
#    Color Size Category  Blue  Green  Red
# 0    Red    s        A     0      0    1
# 1  Green    m        B     0      1    0
# 2   Blue    l        A     1      0    0
# 3  Green    m        A     0      1    0
# 4    Red    l        B     0      0    1
# 5   Blue    s        C     1      0    0

# %%
#------------- 2.label Encoder -------------
label_encoder=LabelEncoder()
df['Color_Label']=label_encoder.fit_transform(df['Color'])
df['Size_Label']=label_encoder.fit_transform(df['Size'])
df['Category_Label']=label_encoder.fit_transform(df['Category'])

print("\nLabel Encoding:")
print(df[['Color','Color_Label','Size','Size_Label','Category','Category_Label']])
# Out:
# Label Encoding:
#    Color  Color_Label Size  Size_Label Category  Category_Label
# 0    Red            2    s           2        A               0
# 1  Green            1    m           1        B               1
# 2   Blue            0    l           0        A               0
# 3  Green            1    m           1        A               0
# 4    Red            2    l           0        B               1
# 5   Blue            0    s           2        C               2

# %%
#---------- 3.Frequency Encoding -------------
freq_encoding=df['Category'].value_counts().to_dict()
df['Category_Frequency']=df['Category'].map(freq_encoding)

print("\nFrequency Encoding:")
print(df[['Category','Category_Frequency']])
# Out:
# Frequency Encoding:
#   Category  Category_Frequency
# 0        A                   3
# 1        B                   2
# 2        A                   3
# 3        A                   3
# 4        B                   2
# 5        C                   1

# %%
#----------- 4. Ordinal Encoding ----------
#Ordinal mapping is based on predefined order
ordinal_mapping={'s':1,'m':2,'l':3}
df['Size_Ordinal']=df['Size'].map(ordinal_mapping)

print("\nOrdinal Encoding:")
print(df[['Size','Size_Ordinal']])
# Out:
# Ordinal Encoding:
#   Size  Size_Ordinal
# 0    s             1
# 1    m             2
# 2    l             3
# 3    m             2
# 4    l             3
# 5    s             1

# %%
#-----------5. mean encoding ------------
mean_encoding=df.groupby('Category')['Size'].apply(lambda x:x.map({'s':1,'m':2,'l':3}).mean())
df['Category_Mean']=df['Category'].map(mean_encoding)

print("\nMean Encoding:")
print(df[['Category','Category_Mean']])
# Out:
# Mean Encoding:
#   Category  Category_Mean
# 0        A            2.0
# 1        B            2.5
# 2        A            2.0
# 3        A            2.0
# 4        B            2.5
# 5        C            1.0
